closeness_centrality_pre = {'^GSPC': 0.6251993620414673, 'SHW': 0.4319559228650137, 'ECL': 0.6091686091686092, 'PPG': 0.7199265381083564, 'BA': 0.4319559228650137, 'CAT': 0.7199265381083564, 'MMM': 0.6251993620414673, 'AMZN': 0.7199265381083564, 'F': 0.8484848484848485, 'NKE': 0.0, 'PG': 0.4319559228650137, 'KO': 0.7199265381083564, 'PEP': 0.6420966420966422, 'JNJ': 0.6420966420966422, 'PFE': 0.5794530672579453, 'MRK': 0.0, 'JPM': 0.4319559228650137, 'BAC': 0.4319559228650137, 'WFC': 0.7199265381083564, 'AAPL': 0.6987522281639929, 'MSFT': 0.0, 'INTC': 0.7199265381083564, 'GOOGL': 0.0, 'T': 0.5794530672579453, 'CMCSA': 0.6987522281639929, 'DUK': 0.7199265381083564, 'SO': 0.5794530672579453, 'D': 0.0, 'SPG': 0.7199265381083564, 'AMT': 0.7199265381083564, 'EQIX': 0.5525017618040874, 'XOM': 0.7199265381083564, 'CVX': 0.7199265381083564, 'SLB': 0.7199265381083564}

# Convert to DataFrame
df_betweenness = pd.DataFrame([betweenness_centrality_pre, betweenness_centrality_post]).T
df_betweenness.columns = ['Pre-Training', 'Post-Training']
df_closeness = pd.DataFrame([closeness_centrality_pre, closeness_centrality_post]).T
df_closeness.columns = ['Pre-Training', 'Post-Training']

# Create a single figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(30, 16))  # Adjust the figure size as necessary

# Plot Betweenness Centrality
df_betweenness.plot(kind='line', marker='o', ax=ax1, title='Betweenness Centrality - October 1-10, 2008')
ax1.set_ylabel('Betweenness Centrality', fontsize=36)
ax1.set_xlabel('Company', fontsize=36)
ax1.set_title('Betweenness Centrality - October 1-10, 2008', fontsize=36)
ax1.tick_params(axis='x', labelrotation=90, labelsize=34)
ax1.tick_params(axis='y', labelsize=34)
ax1.grid(True)
ax1.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax1.set_xticks(range(len(df_betweenness)))
ax1.set_xticklabels(df_betweenness.index)

# Plot Closeness Centrality
df_closeness.plot(kind='line', marker='o', ax=ax2, title='Closeness Centrality - October 1-10, 2008')
ax2.set_ylabel('Closeness Centrality', fontsize=36)
ax2.set_xlabel('Company', fontsize=36)
ax2.set_title('Closeness Centrality - October 1-10, 2008', fontsize=36)
ax2.tick_params(axis='x', labelrotation=90, labelsize=34)
ax2.tick_params(axis='y', labelsize=34)
ax2.grid(True)
ax2.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax2.set_xticks(range(len(df_closeness)))
ax2.set_xticklabels(df_closeness.index)

closeness_centrality_pre = {'^GSPC': 0.0, 'SHW': 0.0, 'ECL': 0.5757575757575758, 'PPG': 0.31255411255411253, 'BA': 0.45580808080808083, 'CAT': 0.29565929565929566, 'MMM': 0.39069264069264076, 'AMZN': 0.4972451790633609, 'F': 0.0, 'NKE': 0.39069264069264076, 'PG': 0.3038720538720539, 'KO': 0.4375757575757576, 'PEP': 0.47562582345191046, 'JNJ': 0.0, 'PFE': 0.0, 'MRK': 0.0, 'JPM': 0.0, 'BAC': 0.39069264069264076, 'WFC': 0.0, 'AAPL': 0.0, 'MSFT': 0.546969696969697, 'INTC': 0.0, 'GOOGL': 0.0, 'T': 0.0, 'CMCSA': 0.39069264069264076, 'DUK': 0.45580808080808083, 'SO': 0.35288367546432065, 'D': 0.4972451790633609, 'SPG': 0.3772204806687565, 'AMT': 0.520923520923521, 'EQIX': 0.33149678604224064, 'XOM': 0.47562582345191046, 'CVX': 0.0, 'SLB': 0.0}

# Convert to DataFrame
df_betweenness = pd.DataFrame([betweenness_centrality_pre, betweenness_centrality_post]).T
df_betweenness.columns = ['Pre-Training', 'Post-Training']
df_closeness = pd.DataFrame([closeness_centrality_pre, closeness_centrality_post]).T
df_closeness.columns = ['Pre-Training', 'Post-Training']

# Create a single figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(30, 16))  # Adjust the figure size as necessary

# Plot Betweenness Centrality
df_betweenness.plot(kind='line', marker='o', ax=ax1, title='Betweenness Centrality - October 25 - November 4, 2016')
ax1.set_ylabel('Betweenness Centrality', fontsize=36)
ax1.set_xlabel('Company', fontsize=36)
ax1.set_title('Betweenness Centrality - October 25 - November 4, 2016', fontsize=36)
ax1.tick_params(axis='x', labelrotation=90, labelsize=34)
ax1.tick_params(axis='y', labelsize=34)
ax1.grid(True)
ax1.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax1.set_xticks(range(len(df_betweenness)))
ax1.set_xticklabels(df_betweenness.index)

# Plot Closeness Centrality
df_closeness.plot(kind='line', marker='o', ax=ax2, title='Closeness Centrality - October 25 - November 4, 2016')
ax2.set_ylabel('Closeness Centrality', fontsize=36)
ax2.set_xlabel('Company', fontsize=36)
ax2.set_title('Closeness Centrality - October 25 - November 4, 2016', fontsize=36)
ax2.tick_params(axis='x', labelrotation=90, labelsize=34)
ax2.tick_params(axis='y', labelsize=34)
ax2.grid(True)
ax2.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax2.set_xticks(range(len(df_closeness)))
ax2.set_xticklabels(df_closeness.index)

plt.tight_layout()
plt.savefig('betweenness_closeness_centrality_comparison_2016.png')
closeness_centrality_pre = {'^GSPC': 0.3492063492063492, 'SHW': 0.5432098765432098, 'ECL': 0.6666666666666666, 'PPG': 0.5238095238095237, 'BA': 0.5238095238095237, 'CAT': 0.0, 'MMM': 0.0, 'AMZN': 0.0, 'F': 0.0, 'NKE': 0.34108527131782945, 'PG': 0.4583333333333333, 'KO': 0.40740740740740744, 'PEP': 0.4444444444444444, 'JNJ': 0.0, 'PFE': 0.35772357723577236, 'MRK': 0.38596491228070173, 'JPM': 0.4731182795698925, 'BAC': 0.0, 'WFC': 0.43137254901960786, 'AAPL': 0.34108527131782945, 'MSFT': 0.0, 'INTC': 0.5238095238095237, 'GOOGL': 0.0, 'T': 0.5057471264367815, 'CMCSA': 0.3492063492063492, 'DUK': 0.5866666666666667, 'SO': 0.40740740740740744, 'D': 0.419047619047619, 'SPG': 0.0, 'AMT': 0.4444444444444444, 'EQIX': 0.5057471264367815, 'XOM': 0.34108527131782945, 'CVX': 0.0, 'SLB': 0.0}

# Convert to DataFrame
df_betweenness = pd.DataFrame([betweenness_centrality_pre, betweenness_centrality_post]).T
df_betweenness.columns = ['Pre-Training', 'Post-Training']
df_closeness = pd.DataFrame([closeness_centrality_pre, closeness_centrality_post]).T
df_closeness.columns = ['Pre-Training', 'Post-Training']

# Create a single figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(30, 16))  # Adjust the figure size as necessary

# Plot Betweenness Centrality
df_betweenness.plot(kind='line', marker='o', ax=ax1, title='Betweenness Centrality - February 20-28, 2020')
ax1.set_ylabel('Betweenness Centrality', fontsize=36)
ax1.set_xlabel('Company', fontsize=36)
ax1.set_title('Betweenness Centrality - February 20-28, 2020', fontsize=36)
ax1.tick_params(axis='x', labelrotation=90, labelsize=34)
ax1.tick_params(axis='y', labelsize=34)
ax1.grid(True)
ax1.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax1.set_xticks(range(len(df_betweenness)))
ax1.set_xticklabels(df_betweenness.index)

# Plot Closeness Centrality
df_closeness.plot(kind='line', marker='o', ax=ax2, title='Closeness Centrality - February 20-28, 2020')
ax2.set_ylabel('Closeness Centrality', fontsize=36)
ax2.set_xlabel('Company', fontsize=36)
ax2.set_title('Closeness Centrality - February 20-28, 2020', fontsize=36)
ax2.tick_params(axis='x', labelrotation=90, labelsize=34)
ax2.tick_params(axis='y', labelsize=34)
ax2.grid(True)
ax2.legend(fontsize=34)

# Ensure all x-tick labels (companies) are displayed
ax2.set_xticks(range(len(df_closeness)))
ax2.set_xticklabels(df_closeness.index)

plt.tight_layout()
plt.savefig('betweenness_closeness_centrality_comparison_2020.png')
plt.show()
